# %%
import pandas as pd
import os

# %%
df = pd.read_csv('data/64fa2910-4d48-469d-92d8-d00086d1e462_2018_2019.csv')
pd.set_option('display.max_columns', 50)

# %%
print(df.columns)
# Out:
# Index(['ocid', 'initiationtype', 'tag', 'id', 'date', 'tender_id',
#        'tender_externalreference', 'tender_title',
#        'tender_mainprocurementcategory', 'tender_procurementmethod',
#        'tender_contracttype', 'tenderclassification_description',
#        'tender_submissionmethoddetails',
#        'tender_participationfee_0_multicurrencyallowed',
#        'tender_allowtwostagetender', 'tender_value_amount',
#        'tender_datepublished', 'tender_milestones_title',
#        'tender_milestones_code', 'tender_milestones_type',
#        'tender_milestones_duedate', 'tender_tenderperiod_durationindays',
#        'tender_allowpreferentialbidder', 'payment_mode', 'tender_status',
#        'tender_stage', 'tender_numberoftenderers', 'tender_milestones_type_1',
#        'tender_milestones_title_1', 'tender_milestones_duedate_1',
#        'tender_bidopening_date', 'tender_documents_id', 'buyer_name',
#        'fiscal_year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9043 entries, 0 to 9042
# Data columns (total 34 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   ocid                                            9043 non-null   object
#  1   initiationtype                                  9043 non-null   object
#  2   tag                                             9043 non-null   object
#  3   id                                              9043 non-null   int64
#  4   date                                            9043 non-null   object
#  5   tender_id                                       9043 non-null   object
#  6   tender_externalreference                        9043 non-null   object
#  7   tender_title                                    9043 non-null   object
#  8   tender_mainprocurementcategory                  9043 non-null   object
#  9   tender_procurementmethod                        9043 non-null   object
#  10  tender_contracttype                             9043 non-null   object
#  11  tenderclassification_description                9043 non-null   object
#  12  tender_submissionmethoddetails                  0 non-null      float64
#  13  tender_participationfee_0_multicurrencyallowed  9043 non-null   object
#  14  tender_allowtwostagetender                      9043 non-null   object
#  15  tender_value_amount                             9043 non-null   int64
#  16  tender_datepublished                            9043 non-null   object
#  17  tender_milestones_title                         9043 non-null   object
#  18  tender_milestones_code                          9043 non-null   object
#  19  tender_milestones_type                          9043 non-null   object
#  20  tender_milestones_duedate                       0 non-null      float64
#  21  tender_tenderperiod_durationindays              9043 non-null   int64
#  22  tender_allowpreferentialbidder                  9043 non-null   object
#  23  payment_mode                                    9043 non-null   object
#  24  tender_status                                   0 non-null      float64
#  25  tender_stage                                    9042 non-null   object
#  26  tender_numberoftenderers                        9043 non-null   int64
#  27  tender_milestones_type_1                        9043 non-null   object
#  28  tender_milestones_title_1                       9043 non-null   object
#  29  tender_milestones_duedate_1                     0 non-null      float64
#  30  tender_bidopening_date                          9043 non-null   object
#  31  tender_documents_id                             127 non-null    object
#  32  buyer_name                                      9043 non-null   object
#  33  fiscal_year                                     9043 non-null   object
# dtypes: float64(4), int64(4), object(26)
# memory usage: 2.3+ MB

# %% [markdown]
# ALL columns are same across csv's.

# %%
folder = "data"
info = {}
for file in os.listdir(folder):
    if file.endswith(".csv"):
        path = os.path.join(folder, file)
        df = pd.read_csv(path, nrows=5)
        base = file.replace(".csv","")
        *_,start_year,end_year = base.split("_")
        print(f"\n{start_year+"_"+end_year}")
        print("Columns:", list(df.columns))
        print("Column count:", len(df.columns))
# Out:
# 2020_2021
# Columns: ['ocid', 'initiationtype', 'tag', 'id', 'date', 'tender_id', 'tender_externalreference', 'tender_title', 'tender_mainprocurementcategory', 'tender_procurementmethod', 'tender_contracttype', 'tenderclassification_description', 'tender_submissionmethoddetails', 'tender_participationfee_0_multicurrencyallowed', 'tender_allowtwostagetender', 'tender_value_amount', 'tender_datepublished', 'tender_milestones_title', 'tender_milestones_code', 'tender_milestones_type', 'tender_milestones_duedate', 'tender_tenderperiod_durationindays', 'tender_allowpreferentialbidder', 'payment_mode', 'tender_status', 'tender_stage', 'tender_numberoftenderers', 'tender_milestones_type_1', 'tender_milestones_title_1', 'tender_milestones_duedate_1', 'tender_bidopening_date', 'tender_documents_id', 'buyer_name', 'fiscal_year']
# Column count: 34
#
# 2018_2019
# Columns: ['ocid', 'initiationtype', 'tag', 'id', 'date', 'tender_id', 'tender_externalreference', 'tender_title', 'tender_mainprocurementcategory', 'tender_procurementmethod', 'tender_contracttype', 'tenderclassification_description', 'tender_submissionmethoddetails', 'tender_participationfee_0_multicurrencyallowed', 'tender_allowtwostagetender', 'tender_value_amount', 'tender_datepublished', 'tender_milestones_title', 'tender_milestones_code', 'tender_milestones_type', 'tender_milestones_duedate', 'tender_tenderperiod_durationindays', 'tender_allowpreferentialbidder', 'payment_mode', 'tender_status', 'tender_stage', 'tender_numberoftenderers', 'tender_milestones_type_1', 'tender_milestones_title_1', 'tender_milestones_duedate_1', 'tender_bidopening_date', 'tender_documents_id', 'buyer_name', 'fiscal_year']
# Column count: 34
#
# 2016_2017
# Columns: ['ocid', 'initiationtype', 'tag', 'id', 'date', 'tender_id', 'tender_externalreference', 'tender_title', 'tender_mainprocurementcategory', 'tender_procurementmethod', 'tender_contracttype', 'tenderclassification_description', 'tender_submissionmethoddetails', 'tender_participationfee_0_multicurrencyallowed', 'tender_allowtwostagetender', 'tender_value_amount', 'tender_datepublished', 'tender_milestones_title', 'tender_milestones_code', 'tender_milestones_type', 'tender_milestones_duedate', 'tender_tenderperiod_durationindays', 'tender_allowpreferentialbidder', 'payment_mode', 'tender_status', 'tender_stage', 'tender_numberoftenderers', 'tender_milestones_type_1', 'tender_milestones_title_1', 'tender_milestones_duedate_1', 'tender_bidopening_date', 'tender_documents_id', 'buyer_name', 'fiscal_year']
# Column count: 34
#
# 2017_2018
# Columns: ['ocid', 'initiationtype', 'tag', 'id', 'date', 'tender_id', 'tender_externalreference', 'tender_title', 'tender_mainprocurementcategory', 'tender_procurementmethod', 'tender_contracttype', 'tenderclassification_description', 'tender_submissionmethoddetails', 'tender_participationfee_0_multicurrencyallowed', 'tender_allowtwostagetender', 'tender_value_amount', 'tender_datepublished', 'tender_milestones_title', 'tender_milestones_code', 'tender_milestones_type', 'tender_milestones_duedate', 'tender_tenderperiod_durationindays', 'tender_allowpreferentialbidder', 'payment_mode', 'tender_status', 'tender_stage', 'tender_numberoftenderers', 'tender_milestones_type_1', 'tender_milestones_title_1', 'tender_milestones_duedate_1', 'tender_bidopening_date', 'tender_documents_id', 'buyer_name', 'fiscal_year']
# Column count: 34
#
# 2021_2022
# Columns: ['ocid', 'initiationtype', 'tag', 'id', 'date', 'tender_id', 'tender_externalreference', 'tender_title', 'tender_mainprocurementcategory', 'tender_procurementmethod', 'tender_contracttype', 'tenderclassification_description', 'tender_submissionmethoddetails', 'tender_participationfee_0_multicurrencyallowed', 'tender_allowtwostagetender', 'tender_value_amount', 'tender_datepublished', 'tender_milestones_title', 'tender_milestones_code', 'tender_milestones_type', 'tender_milestones_duedate', 'tender_tenderperiod_durationindays', 'tender_allowpreferentialbidder', 'payment_mode', 'tender_status', 'tender_stage', 'tender_numberoftenderers', 'tender_milestones_type_1', 'tender_milestones_title_1', 'tender_milestones_duedate_1', 'tender_bidopening_date', 'tender_documents_id', 'buyer_name', 'fiscal_year']
# Column count: 34
#
# 2019_2020
# Columns: ['ocid', 'initiationtype', 'tag', 'id', 'date', 'tender_id', 'tender_externalreference', 'tender_title', 'tender_mainprocurementcategory', 'tender_procurementmethod', 'tender_contracttype', 'tenderclassification_description', 'tender_submissionmethoddetails', 'tender_participationfee_0_multicurrencyallowed', 'tender_allowtwostagetender', 'tender_value_amount', 'tender_datepublished', 'tender_milestones_title', 'tender_milestones_code', 'tender_milestones_type', 'tender_milestones_duedate', 'tender_tenderperiod_durationindays', 'tender_allowpreferentialbidder', 'payment_mode', 'tender_status', 'tender_stage', 'tender_numberoftenderers', 'tender_milestones_type_1', 'tender_milestones_title_1', 'tender_milestones_duedate_1', 'tender_bidopening_date', 'tender_documents_id', 'buyer_name', 'fiscal_year']
# Column count: 34
